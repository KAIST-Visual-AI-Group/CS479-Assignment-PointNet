# %%
# connect to google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Move to work directory
# %cd /content/drive/MyDrive/{path_to_dir}/CS479-Assignment-PointNet/pointnet

# %%
# Confirm current directory
# %ls

# %%
# !python -u train_cls.py --amp --epochs 20

# %%
# !python -u train_seg.py --amp --epochs 20
